# %% [markdown]
# # Код для построения графиков
# Использован фреймворк 'pandas' и библиотека matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Построение графика массива случайных элементов

# %%
df = pd.read_csv("random_arr.csv", delimiter=";")
print(df.head(10))

plt.figure(figsize=(10, 6))
plt.grid(True)
plt.plot(df["size"], df["qsort"], label="qsort")
plt.plot(df["size"], df["mysort"], label="Модифицированная сортировка пузырьком")
plt.plot(
    df["size"], df["bublesort"], color="green", label="Обычная сортировка пузырьком"
)
plt.scatter(df["size"], df["qsort"], color="blue", s=2)
plt.scatter(df["size"], df["mysort"], color="orange", s=2)
plt.scatter(df["size"], df["bublesort"], color="green", s=2)
plt.xlabel("Размеры массива")
plt.ylabel("Время выполнения")
plt.title("Время сортировки рандомного массива")
plt.legend(loc="upper left")
plt.savefig("random_arr.svg")
# Out:
#    size       qsort        mysort     bublesort
# 0     1     20.8000  2.960000e+01  0.000000e+00
# 1   126   2779.0304  9.806667e+04  9.893750e+04
# 2   251   5214.7651  3.390667e+05  3.170667e+05
# 3   376   7902.2556  6.885333e+05  6.371333e+05
# 4   501   9256.7568  1.068467e+06  1.043400e+06
# 5   626  11854.1667  1.651600e+06  1.633467e+06
# 6   751  17576.4192  2.415200e+06  2.395933e+06
# 7   876  19312.9771  3.268600e+06  3.242600e+06
# 8  1001  24505.2632  4.210867e+06  4.188667e+06
# 9  1126  28608.6957  5.388867e+06  5.383933e+06

# %%
df = pd.read_csv("sort_arr.csv", delimiter=";")
print(df.tail(10))

plt.figure(figsize=(10, 6))
plt.grid(True)
plt.plot(df["size"], df["qsort"], label="qsort")
plt.plot(df["size"], df["mysort"], label="Модифицированная сортировка пузырьком")
plt.plot(df["size"], df["bublesort"], color="green", label="Обычная сортировка пузырьком")
plt.scatter(df["size"], df["qsort"], color="blue", s=2)
plt.scatter(df["size"], df["mysort"], color="orange", s=2)
plt.scatter(df["size"], df["bublesort"], color="green", s=2)
plt.xlabel("Размеры массива")
plt.ylabel("Время выполнения")
plt.title("Время сортировки отсортированного массива")
plt.legend(loc="upper left")
plt.savefig("sort_arr.svg")
# Out:
#     size       qsort      mysort   bublesort
# 30  3751  12800.0000   8323.5294   8266.6667
# 31  3876  13066.6667   8500.0000   8555.5556
# 32  4001  13550.0000   8809.5238   8842.1053
# 33  4126  14066.6667   9066.6667   9000.0000
# 34  4251  14466.6667   9333.3333   9413.7931
# 35  4376  14933.3333   9517.2414   9571.4286
# 36  4501  15200.0000   9933.3333   9866.6667
# 37  4626  15733.3333  10222.2222  10222.2222
# 38  4751  16200.0000  10000.0000  10541.6667
# 39  4876  16666.6667  10800.0000  10700.0000

# %%
df = pd.read_csv("reverse_sort_arr.csv", delimiter=";")
print(df.tail(10))

plt.figure(figsize=(10, 6))
plt.grid(True)
plt.plot(df["size"], df["qsort"], label="qsort")
plt.plot(df["size"], df["mysort"], label="Модифицированная сортировка пузырьком")
plt.plot(df["size"], df["bublesort"], color="green", label="Обычная сортировка пузырьком")
plt.scatter(df["size"], df["qsort"], color="blue", s=2)
plt.scatter(df["size"], df["mysort"], color="orange", s=2)
plt.scatter(df["size"], df["bublesort"], color="green", s=2)
plt.xlabel("Размеры массива")
plt.ylabel("Время выполнения")
plt.title("Время сортировки обратно отсортированного массива")
plt.legend(loc="upper left")
plt.savefig("reverse_sort_arr.svg")
# Out:
#     size       qsort        mysort     bublesort
# 30  3751  61066.6667  8.075140e+07  8.205773e+07
# 31  3876  62647.0588  8.664713e+07  9.209697e+07
# 32  4001  66400.0000  9.673598e+07  9.316153e+07
# 33  4126  67650.0000  9.893513e+07  9.904540e+07
# 34  4251  68866.6667  1.051667e+08  1.058630e+08
# 35  4376  73266.6667  1.173077e+08  1.137208e+08
# 36  4501  73533.3333  1.215620e+08  1.226901e+08
# 37  4626  75200.0000  1.254947e+08  1.246607e+08
# 38  4751  81301.2658  1.318558e+08  1.320623e+08
# 39  4876  83600.0000  1.399676e+08  1.392865e+08
