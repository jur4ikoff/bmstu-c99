# %% [markdown]
# # Код для построения графиков
# Использован фреймворк 'pandas' и библиотека matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Построение графика массива случайных элементов

# %%
df = pd.read_csv("random_arr.csv", delimiter=";")
print(df.head(10))

plt.figure(figsize=(10, 6))
plt.grid(True)
plt.plot(df["size"], df["qsort"], label="qsort")
plt.plot(df["size"], df["mysort"], label="Модифицированная сортировка пузырьком")
plt.plot(
    df["size"], df["bublesort"], color="green", label="Обычная сортировка пузырьком"
)
plt.scatter(df["size"], df["qsort"], color="blue", s=2)
plt.scatter(df["size"], df["mysort"], color="orange", s=2)
plt.scatter(df["size"], df["bublesort"], color="green", s=2)
plt.xlabel("Размеры массива")
plt.ylabel("Время выполнения")
plt.title("Время сортировки рандомного массива")
plt.legend(loc="upper left")
plt.savefig("random_arr.svg")
# Out:
#    size       qsort        mysort     bublesort
# 0     1     38.0000  3.600000e+01  0.000000e+00
# 1   126   4911.7647  1.762000e+05  1.756667e+05
# 2   251   9337.9630  5.641250e+05  4.935455e+05
# 3   376   9636.0294  6.399005e+05  5.878000e+05
# 4   501   8552.2388  1.053467e+06  1.056133e+06
# 5   626  11519.5531  1.710000e+06  1.697800e+06
# 6   751  15370.1657  2.383667e+06  2.394867e+06
# 7   876  19991.8699  3.250200e+06  3.258800e+06
# 8  1001  24210.5263  4.273867e+06  4.389600e+06
# 9  1126  30764.2857  5.731400e+06  5.650267e+06

# %%
df = pd.read_csv("sort_arr.csv", delimiter=";")
print(df.tail(10))

plt.figure(figsize=(10, 6))
plt.grid(True)
plt.plot(df["size"], df["qsort"], label="qsort")
plt.plot(df["size"], df["mysort"], label="Модифицированная сортировка пузырьком")
plt.plot(df["size"], df["bublesort"], color="green", label="Обычная сортировка пузырьком")
plt.scatter(df["size"], df["qsort"], color="blue", s=2)
plt.scatter(df["size"], df["mysort"], color="orange", s=2)
plt.scatter(df["size"], df["bublesort"], color="green", s=2)
plt.xlabel("Размеры массива")
plt.ylabel("Время выполнения")
plt.title("Время сортировки отсортированного массива")
plt.legend(loc="upper left")
plt.savefig("sort_arr.svg")
# Out:
#     size      qsort     mysort  bublesort
# 6    751  2723.2472  1770.0000  1738.0000
# 7    876  3043.4783  1940.3974  1942.8571
# 8   1001  3524.7525  2208.8235  2247.9784
# 9   1126  3961.5385  2506.2657  2584.6995
# 10  1251  4521.5606  2792.0000  2813.4715
# 11  1376  4772.1519  3000.0000  3043.4783
# 12  1501  5235.2941  3328.3582  3336.6337
# 13  1626  5652.7778  3718.1208  3721.0884
# 14  1751  6204.5455  4000.0000  4000.0000
# 15  1876  6542.3729  4371.2871  4000.0000

# %%
df = pd.read_csv("reverse_sort_arr.csv", delimiter=";")
print(df.tail(10))

plt.figure(figsize=(10, 6))
plt.grid(True)
plt.plot(df["size"], df["qsort"], label="qsort")
plt.plot(df["size"], df["mysort"], label="Модифицированная сортировка пузырьком")
plt.plot(df["size"], df["bublesort"], color="green", label="Обычная сортировка пузырьком")
plt.scatter(df["size"], df["qsort"], color="blue", s=2)
plt.scatter(df["size"], df["mysort"], color="orange", s=2)
plt.scatter(df["size"], df["bublesort"], color="green", s=2)
plt.xlabel("Размеры массива")
plt.ylabel("Время выполнения")
plt.title("Время сортировки обратно отсортированного массива")
plt.legend(loc="upper left")
plt.savefig("reverse_sort_arr.svg")
# Out:
#     size      qsort     mysort  bublesort
# 6    751  2723.2472  1770.0000  1738.0000
# 7    876  3043.4783  1940.3974  1942.8571
# 8   1001  3524.7525  2208.8235  2247.9784
# 9   1126  3961.5385  2506.2657  2584.6995
# 10  1251  4521.5606  2792.0000  2813.4715
# 11  1376  4772.1519  3000.0000  3043.4783
# 12  1501  5235.2941  3328.3582  3336.6337
# 13  1626  5652.7778  3718.1208  3721.0884
# 14  1751  6204.5455  4000.0000  4000.0000
# 15  1876  6542.3729  4371.2871  4000.0000
